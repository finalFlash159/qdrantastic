# %% [markdown]
# ## Fast Embeded

# %%
from typing import List
import numpy as np

# %% [markdown]
# ### Load default model (BAAI/bge-small-en-v1.5)

# %%
from fastembed import TextEmbedding

# %%
embedding_model = TextEmbedding()
print("The model BAAI/bge-small-en-v1.5 is ready to use.")
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model_optimized.onnx:   0%|          | 0.00/66.5M [00:00<?, ?B/s]
# The model BAAI/bge-small-en-v1.5 is ready to use.

# %% [markdown]
# ### Sample data

# %%
documents: List[str] = [
    "FastEmbed is lighter than Transformers & Sentence-Transformers.",
    "FastEmbed is supported by and maintained by Qdrant.",
]

# %% [markdown]
# ### Embed data

# %%
embeddings_generator = embedding_model.embed(documents)
embeddings_list = list(embeddings_generator)
len(embeddings_list[0])
# Out:
# 384

# %%
print("Embeddings:\n", embeddings_list)
# Out:
# Embeddings:
#  [array([-9.47402492e-02,  1.00907953e-02, -3.08784992e-02,  2.37383470e-02,
#         2.35118857e-03,  6.27760717e-04, -8.24847594e-02,  8.47143936e-04,
#         3.71927395e-02,  1.43602341e-02, -2.38315947e-02,  8.75035126e-04,
#         3.01857982e-02,  4.09759544e-02,  4.37467620e-02,  8.65210779e-03,
#         5.06204925e-02, -1.26484623e-02, -3.13580632e-02,  2.06078682e-02,
#         8.13657790e-02, -5.41905686e-02,  1.02106864e-02, -4.58781496e-02,
#        -7.70630362e-03, -3.52212042e-02, -2.35518496e-02, -2.68954672e-02,
#        -2.73883492e-02, -1.57296523e-01,  1.25152506e-02, -3.55941989e-02,
#         6.44212365e-02, -1.33711367e-03, -3.40489410e-02,  9.80438944e-03,
#        -3.25036831e-02,  1.50529351e-02, -6.96964264e-02, -1.67580470e-02,
#        -2.34719217e-02,  2.00483780e-02, -1.56124253e-02,  1.41620811e-03,
#        -1.32012917e-02, -2.17135269e-02,  6.86307326e-02, -2.02348754e-02,
#        -9.11168847e-03, -1.49064027e-02,  6.37818202e-02,  1.36075877e-02,
#         7.07088336e-02,  3.03190108e-02,  8.15256312e-03, -2.50171795e-02,
#         2.69887149e-02,  5.54694012e-02,  5.20325378e-02, -2.93865278e-02,
#        -9.14166099e-04,  4.40131836e-02, -1.02573104e-01,  5.15263304e-02,
#         1.34677151e-02, -4.58248667e-02, -4.80361804e-02, -9.61789340e-02,
#        -7.82752633e-02,  3.70861702e-02,  3.67664620e-02, -9.69782006e-03,
#        -1.16626946e-02,  4.24945690e-02, -2.03680880e-02,  1.77704562e-02,
#         3.18642668e-02, -2.52036769e-02, -4.63743636e-04, -6.28593261e-04,
#         7.12416843e-02, -6.46876618e-02, -1.00068718e-01,  1.10765630e-02,
#        -8.40833038e-02, -5.54161184e-02,  2.31255721e-02, -2.19666287e-02,
#         6.10776199e-03,  2.23529432e-02, -5.91993332e-02, -2.17401683e-02,
#         1.69845074e-02,  2.59363409e-02, -5.93791669e-03, -4.93150167e-02,
#        -1.40138837e-02,  3.53810601e-02, -4.23080735e-02,  3.94733250e-01,
#        -3.48748527e-02,  2.32054982e-02,  6.86040847e-03, -1.82100553e-02,
#         7.16146752e-02, -1.43202702e-02,  2.64691878e-02, -2.68155392e-02,
#        -2.48706471e-02,  9.50466376e-03, -6.46410370e-03, -1.98085979e-02,
#         0.06720719,  0.01169405, -0.00446256, -0.01237957,  0.05465289,
#         0.03723279, -0.11064993, -0.00432478,  0.01920782, -0.04107704,
#         0.02774313, -0.04970644, -0.01876425, -0.03346918, -0.06752979,
#        -0.00599824,  0.05559379,  0.00633428,  0.03997484,  0.03916835,
#         0.02661405, -0.03354983,  0.03397996,  0.03008194, -0.05898103,
#        -0.04228677, -0.03524345,  0.09038024, -0.03932965,  0.01555174,
#         0.03715214,  0.00268493, -0.01982612, -0.04043185,  0.02242032,
#        -0.1081767 ,  0.00171126,  0.00052632, -0.04416857,  0.03207127,
#         0.03174868, -0.02306551,  0.00356198,  0.04196417,  0.04717945,
#         0.04774399, -0.08898233,  0.02591509, -0.02567315,  0.02533711,
#         0.00331668,  0.00959047,  0.07753022,  0.01998742,  0.03481333,
#        -0.02978623, -0.00793045,  0.01249382,  0.03459826, -0.25850576,
#        -0.01389845, -0.04986774, -0.06188438, -0.06769109,  0.00542698,
#        -0.04500194, -0.03989419,  0.04123833,  0.03330788,  0.02395264,
#         0.04884619,  0.08957375,  0.01272904,  0.00683161, -0.00855548,
#         0.07419674, -0.01606252,  0.01384468, -0.05844337,  0.00453313,
#        -0.01422104,  0.14581273, -0.02242032, -0.01440922,  0.03295841,
#        -0.01003403, -0.01172766, -0.01354225, -0.03016259, -0.01584746,
#        -0.02997441,  0.07650867, -0.07812164, -0.04320078,  0.0265334 ,
#        -0.00190196, -0.00770866,  0.00786324,  0.02400641, -0.0070702 ,
#        -0.0024497 , -0.01824003,  0.02940987,  0.02107618, -0.02176169,
#         0.02975935, -0.00793717,  0.03561981,  0.06521786, -0.04371156,
#        -0.05543249,  0.02657373, -0.01116984, -0.01682868, -0.05984129,
#        -0.03145297,  0.06521786,  0.01803841, -0.02606295,  0.01626414,
#        -0.03682954,  0.03970601,  0.02760871,  0.03306594], dtype=float32)]

# %% [markdown]
# ## Fast Embeded & Qdrant

# %% [markdown]
# ### Inital the client
# Qdrant Client has a simple in-memory mode that lets you try semantic search locally.

# %%
from qdrant_client import QdrantClient

client = QdrantClient(":memory:")  # Qdrant is running from RAM.

# %% [markdown]
# ### Sample data

# %%
docs = ["Qdrant has a LangChain integration for chatbots.", "Qdrant has a LlamaIndex integration for agents."]
metadata = [
    {"source": "langchain-docs"},
    {"source": "llamaindex-docs"},
]
ids = [42, 2]

# %% [markdown]
# ### Load data to a collection

# %%
# Create a test collection and upsert your two documents to it.
client.add(
    collection_name="test_collection",
    documents=docs,
    metadata=metadata,
    ids=ids
)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# model_optimized.onnx:   0%|          | 0.00/133M [00:00<?, ?B/s]
# [42, 2]

# %% [markdown]
# ### Vector Search

# %%
search_result = client.query(
    collection_name="test_collection",
    query_text="Which integration is best for agents?"
)
print(search_result)
# Out:
# [QueryResponse(id=2, embedding=None, sparse_embedding=None, metadata={'document': 'Qdrant has a LlamaIndex integration for agents.', 'source': 'llamaindex-docs'}, document='Qdrant has a LlamaIndex integration for agents.', score=0.87491801319731), QueryResponse(id=42, embedding=None, sparse_embedding=None, metadata={'document': 'Qdrant has a LangChain integration for chatbots.', 'source': 'langchain-docs'}, document='Qdrant has a LangChain integration for chatbots.', score=0.8351846627714035)]
